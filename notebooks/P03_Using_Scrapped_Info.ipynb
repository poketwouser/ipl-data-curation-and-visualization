# %% [markdown]
# # Loading Data:

# %%
import numpy as np
import pandas as pd
import import_ipynb

# %%
from P01_Pre_Processing import matches, trimSpaceInValues, title, latest_teams
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1095 non-null   int64
#  1   season           1095 non-null   object
#  2   city             1044 non-null   object
#  3   date             1095 non-null   object
#  4   match_type       1095 non-null   object
#  5   player_of_match  1090 non-null   object
#  6   venue            1095 non-null   object
#  7   team1            1095 non-null   object
#  8   team2            1095 non-null   object
#  9   toss_winner      1095 non-null   object
#  10  toss_decision    1095 non-null   object
#  11  winner           1090 non-null   object
#  12  result           1095 non-null   object
#  13  result_margin    1076 non-null   float64
#  14  target_runs      1092 non-null   float64
#  15  target_overs     1092 non-null   float64
#  16  super_over       1095 non-null   object
#  17  method           21 non-null     object
#  18  umpire1          1095 non-null   object
#  19  umpire2          1095 non-null   object
# dtypes: float64(3), int64(1), object(16)
# memory usage: 171.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260920 entries, 0 to 260919
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          260920 non-null  int64
#  1   inning            260920 non-null  int64
#  2   batting_team      260920 non-null  object
#  3   bowling_team      260920 non-null  object
#  4   over              260920 non-null  int64
#  5   ball              260920 non-null  int64
#  6   batter            260920 non-null  object
#  7   bowler            260920 non-null  object
#  8   non_striker       260920 non-null  object
#  9   batsman_runs      260920 non-null  int64
#  10  extra_runs        260920 non-null  int64
#  11  total_runs        260920 non-null  int64
#  12  extras_type       14125 non-null   object
#  13  is_wicket         260920 non-null  int64
#  14  player_dismissed  12950 non-null   object
#  15  dismissal_kind    12950 non-null   object
#  16  fielder           9354 non-null    object
# dtypes: int64(8), object(9)
# memory usage: 33.8+ MB

# %%
all_matches = pd.read_csv('../data/raw/all_matches.csv')

# %%
all_matches = latest_teams(all_matches, ['Team 1', 'Team 2'])
all_matches = trimSpaceInValues(all_matches)
all_matches = title(all_matches)

# %%
all_matches.head()
# Out:
#      Match                       Team 1                       Team 2  \
# 0  Match 1  Royal Challengers Bangalore        Kolkata Knight Riders
# 1  Match 2                 Punjab Kings          Chennai Super Kings
# 2  Match 3               Delhi Capitals             Rajasthan Royals
# 3  Match 4        Kolkata Knight Riders          Sunrisers Hyderabad
# 4  Match 5               Mumbai Indians  Royal Challengers Bangalore
#
#          Date     Time  Season
# 0  2008-04-18  8:00 pm    2008
# 1  2008-04-19  4:00 pm    2008
# 2  2008-04-19  8:00 pm    2008
# 3  2008-04-20  4:00 pm    2008
# 4  2008-04-20  8:00 pm    2008

# %%
matches.head()
# Out:
#        Id  Season        City        Date Match_Type Player_Of_Match  \
# 0  335982    2008   Bangalore  2008-04-18     League     BB McCullum
# 1  335983    2008  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984    2008       Delhi  2008-04-19     League     MF Maharoof
# 3  335985    2008      Mumbai  2008-04-20     League      MV Boucher
# 4  335986    2008     Kolkata  2008-04-20     League       DJ Hussey
#
#                                           Venue                        Team1  \
# 0                         M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association IS Bindra Stadium                 Punjab Kings
# 2                          Arun Jaitley Stadium               Delhi Capitals
# 3                              Wankhede Stadium               Mumbai Indians
# 4                                  Eden Gardens        Kolkata Knight Riders
#
#                          Team2                  Toss_Winner Toss_Decision  \
# 0        Kolkata Knight Riders  Royal Challengers Bangalore         Field
# 1          Chennai Super Kings          Chennai Super Kings           Bat
# 2             Rajasthan Royals             Rajasthan Royals           Bat
# 3  Royal Challengers Bangalore               Mumbai Indians           Bat
# 4          Sunrisers Hyderabad          Sunrisers Hyderabad           Bat
#
#                         Winner   Result Result_Margin Target_Runs  \
# 0        Kolkata Knight Riders     Runs           140         223
# 1          Chennai Super Kings     Runs            33         241
# 2               Delhi Capitals  Wickets             9         130
# 3  Royal Challengers Bangalore  Wickets             5         166
# 4        Kolkata Knight Riders  Wickets             5         111
#
#   Target_Overs Super_Over  Method    Umpire1         Umpire2
# 0           20          N  Normal  Asad Rauf     RE Koertzen
# 1           20          N  Normal  MR Benson      SL Shastri
# 2           20          N  Normal  Aleem Dar  GA Pratapkumar
# 3           20          N  Normal   SJ Davis       DJ Harper
# 4           20          N  Normal  BF Bowden     K Hariharan

# %% [markdown]
# # Processing Data:

# %%
# After careful examination, from espncricinfo.com and iplt20.com, we figured out the Matc 24 data was missing in iplt20.com data

# %%
# --- Step 1: Create the new match row ---
new_row = {
    'Match': 'Match 24',
    'Team 1': 'Chennai Super Kings',
    'Team 2': 'Pune Warriors India',
    'Date': pd.to_datetime('2012-04-19'),
    'Time': '8:00 pm',
    'Season': 2012
}

# --- Step 2: Insert at index 275 ---
before = all_matches.iloc[:275]
after = all_matches.iloc[275:]
all_matches = pd.concat([before, pd.DataFrame([new_row]), after], ignore_index=True)

# --- Step 3: Extract numeric match number safely ---
all_matches['Match_Num'] = (
    all_matches['Match']
    .astype(str)
    .str.extract(r'(\d+)')[0]
)
all_matches['Match_Num'] = pd.to_numeric(all_matches['Match_Num'], errors='coerce')

# --- Step 4: Identify the newly inserted row (the one at index 275) ---
new_row_index = 275  # or dynamically find via something like: all_matches.query("Team1 == 'Chennai Super Kings' and Team2 == 'Pune Warriors India'").index[0]

# --- Step 5: Increment match numbers for Season 2012, >= 24, but not the new row ---
mask = (
    (all_matches['Season'] == 2012) &
    (all_matches['Match_Num'] >= 24) &
    (all_matches.index != new_row_index)
)
all_matches.loc[mask, 'Match_Num'] = all_matches.loc[mask, 'Match_Num'] + 1

# --- Step 6: Rebuild safely ---
all_matches['Match_Num'] = all_matches['Match_Num'].astype('Int64')
all_matches.loc[all_matches['Match_Num'].notna(), 'Match'] = 'Match ' + all_matches['Match_Num'].astype(str)
all_matches.drop(columns=['Match_Num'], inplace=True)

# %%
# Due to rain, reserve day was used. Matches uses the scheduled date

# %%
matches.loc[matches['Id'] == 734043, 'Date'] = pd.to_datetime('2014-05-28')

# %%
# Step 1: Convert to datetime safely
all_matches['Date'] = pd.to_datetime(all_matches['Date'], errors='coerce')

# Step 2: (Optional) Keep only the date part (drop the time component)
all_matches['Date'] = all_matches['Date'].dt.date

# %%
display(all_matches.loc[270:280])
# Out:
#         Match                       Team 1                       Team 2  \
# 270  Match 19               Mumbai Indians               Delhi Capitals
# 271  Match 20             Rajasthan Royals          Sunrisers Hyderabad
# 272  Match 21  Royal Challengers Bangalore          Pune Warriors India
# 273  Match 22                 Punjab Kings        Kolkata Knight Riders
# 274  Match 23               Delhi Capitals          Sunrisers Hyderabad
# 275  Match 24          Chennai Super Kings          Pune Warriors India
# 276  Match 25                 Punjab Kings  Royal Challengers Bangalore
# 277  Match 26          Chennai Super Kings             Rajasthan Royals
# 278  Match 27               Delhi Capitals          Pune Warriors India
# 279  Match 28               Mumbai Indians                 Punjab Kings
# 280  Match 29          Sunrisers Hyderabad        Kolkata Knight Riders
#
#            Date     Time  Season
# 270  2012-04-16  8:00 pm    2012
# 271  2012-04-17  4:00 pm    2012
# 272  2012-04-17  8:00 pm    2012
# 273  2012-04-18  8:00 pm    2012
# 274  2012-04-19  4:00 pm    2012
# 275  2012-04-19  8:00 pm    2012
# 276  2012-04-20  8:00 pm    2012
# 277  2012-04-21  4:00 pm    2012
# 278  2012-04-21  8:00 pm    2012
# 279  2012-04-22  4:00 pm    2012
# 280  2012-04-22  8:00 pm    2012

# %% [markdown]
# # Concatenating:

# %%
all_matches['Date'] = pd.to_datetime(all_matches['Date'])
all_matches['match_key'] = all_matches.apply(lambda x: tuple(sorted([x['Team 1'], x['Team 2']])), axis=1)
all_matches.rename(columns={'Match': 'Match_No', 'Time': 'Time'}, inplace=True)

# %%
matches['Date'] = pd.to_datetime(matches['Date'])
matches['match_key'] = matches.apply(lambda x: tuple(sorted([x['Team1'], x['Team2']])), axis=1)

# %%
def merge_match_data(all_matches = all_matches, matches = matches):
    """Merge both datasets using Season, Date, and team match_key."""
    
    merged = pd.merge(
        matches,
        all_matches[['Season', 'Date', 'match_key', 'Time', 'Match_No']],
        on=['Season', 'Date', 'match_key'],
        how='left',
        indicator=True
    )
    
    return merged

# %%
def find_unmatched_rows(merged, all_matches = all_matches, matches = matches):
    """Find rows that didn’t match in either dataset."""
    used_all = merged.dropna(subset=['Match_No'])[['Season', 'Date', 'match_key']]
    
    # Unmatched from matches
    unmatched_matches = merged[merged['_merge'] == 'left_only']
    
    # Unmatched from all_matches
    all_matches_keys = all_matches[['Season', 'Date', 'match_key']]
    used_keys = used_all[['Season', 'Date', 'match_key']]
    unmatched_all_matches = all_matches_keys.merge(used_keys, on=['Season', 'Date', 'match_key'], how='left', indicator=True)
    unmatched_all_matches = unmatched_all_matches[unmatched_all_matches['_merge'] == 'left_only']

    unmatched_matches = pd.DataFrame(unmatched_matches)
    unmatched_all_matches = pd.DataFrame(unmatched_all_matches)
    
    return unmatched_matches, unmatched_all_matches

# %%
matches = merge_match_data(all_matches, matches)

unmatched_matches, unmatched_all_matches = find_unmatched_rows(matches, all_matches, matches)

# %%
print("✅ Merged dataset shape:", matches.shape)
print("❌ Unmatched in matches:", len(unmatched_matches))
print("❌ Unmatched in all_matches:", len(unmatched_all_matches))
# Out:
# ✅ Merged dataset shape: (1095, 24)
# ❌ Unmatched in matches: 0
# ❌ Unmatched in all_matches: 11

# %%
for i in range(2008, 2025):
    count = len(all_matches[all_matches['Season'] == i])
    print(f"{i}: {count} matches")
# Out:
# 2008: 59 matches
# 2009: 59 matches
# 2010: 60 matches
# 2011: 74 matches
# 2012: 76 matches
# 2013: 76 matches
# 2014: 60 matches
# 2015: 60 matches
# 2016: 60 matches
# 2017: 60 matches
# 2018: 60 matches
# 2019: 60 matches
# 2020: 60 matches
# 2021: 60 matches
# 2022: 74 matches
# 2023: 74 matches
# 2024: 74 matches

# %%
unmatched_all_matches
# Out:
#       Season       Date                                          match_key  \
# 46      2008 2008-05-22            (Delhi Capitals, Kolkata Knight Riders)
# 65      2009 2009-04-21                 (Mumbai Indians, Rajasthan Royals)
# 71      2009 2009-04-25       (Chennai Super Kings, Kolkata Knight Riders)
# 197     2011 2011-04-19    (Rajasthan Royals, Royal Challengers Bangalore)
# 283     2012 2012-04-24       (Kolkata Knight Riders, Sunrisers Hyderabad)
# 285     2012 2012-04-25  (Chennai Super Kings, Royal Challengers Bangal...
# 488     2015 2015-04-26          (Kolkata Knight Riders, Rajasthan Royals)
# 612     2017 2017-04-25  (Royal Challengers Bangalore, Sunrisers Hydera...
# 1094    2024 2024-05-13            (Gujarat Titans, Kolkata Knight Riders)
# 1097    2024 2024-05-16              (Gujarat Titans, Sunrisers Hyderabad)
# 1101    2024 2024-05-19          (Kolkata Knight Riders, Rajasthan Royals)
#
#          _merge
# 46    left_only
# 65    left_only
# 71    left_only
# 197   left_only
# 283   left_only
# 285   left_only
# 488   left_only
# 612   left_only
# 1094  left_only
# 1097  left_only
# 1101  left_only
